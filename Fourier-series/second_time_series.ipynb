# %%
import numpy as np
import matplotlib.pyplot as plt

# f(x) = x**2

n = 3
x = np.linspace(-np.pi, np.pi, 1000);
F = 0

for i in range(n):
    i += 1
    F = F + ((4*(-1)**i)/(i**2)*np.cos(i*x))

F = F + np.pi**2/3
plt.plot(x, F, x, x**2)

plt.show()
