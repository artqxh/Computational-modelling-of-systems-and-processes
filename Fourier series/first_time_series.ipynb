# %%
# f(x) = x

import numpy as np
import matplotlib.pyplot as plt

n = 25
x = np.linspace(-np.pi, np.pi, 1000);
F = 0

for i in range(n):
    i += 1
    F = F + (-2/i*(-1)**(i)*np.sin(i*x))

plt.plot(x, F)
plt.show()
